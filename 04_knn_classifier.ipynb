# %% [markdown]
# # NOTEBOOK: K-Nearest Neighbors Classification
#
#  Goal: Implement and evaluate K-Nearest Neighbors Classifier
#  Supports TWO implementations of KNN:
#
# 1. FROM-SCRATCH: Pure NumPy implementation
#    - Pure NumPy, no sklearn dependencies (for core algorithm)
#    - Demonstrates understanding of KNN mechanics
#    - Clean, readable code with clear documentation
#    - Supports all key features: distance metrics, weighted voting
#    - API-compatible with sklearn (drop-in replacement)
#
# 2. SKLEARN: Industry standard
#    - Industry standard, battle-tested
#    - Optimized C implementation for speed
#    - Production-ready
#
# Toggle between them by changing USE_SCRATCH_IMPLEMENTATION below.
# Both produce IDENTICAL results

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src import data_loader
from src.eda import (
    analyze_data,
    plot_feature_distributions_by_class
)
from src.preprocessing import DataPreprocessor
from src.data_utils import split_train_test

USE_SCRATCH_IMPLEMENTATION = False  # 👈 CHANGE THIS TO SWITCH

if USE_SCRATCH_IMPLEMENTATION:
    from src.models.supervised import ScratchKNNClassifier as KNN
    print("✅ Using FROM-SCRATCH implementation")
else:
    from src.models.supervised import SKLearnKNNClassifier as KNN
    print("✅ Using SKLEARN implementation")

from src.models.supervised import SKLearnLDA

from src.models.supervised.model_selection import (
    k_fold_cross_validation, 
    plot_cross_validation_results,
    grid_search_cv,
    plot_grid_search_results
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ✅ Using SKLEARN implementation

# %% [markdown]
# ## Data Loading & Exploration

# %%
# Load data
# Quick EDA: shape, dtypes, missing values, class distribution
# Feature/target split

X, y = data_loader.load_titanic()

analyze_data(X, show_stats=True)
plot_feature_distributions_by_class(X, y)
# Out:
# ======================================================================
# DATA ANALYSIS
# ======================================================================
#
# Dataset shape: 891 rows × 7 columns
#
# Data types:
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Embarked     object
# dtype: object
#
# Missing values:
#           Missing_Count  Missing_Percent
# Age                 177            19.87
# Embarked              2             0.22
#
# Numerical columns (5):
# ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
#
# Categorical columns (2):
# ['Sex', 'Embarked']
#
# Numerical features statistics:
#            Pclass         Age       SibSp       Parch        Fare
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200
# ======================================================================

# %% [markdown]
# ## Preprocess Data

# %%
# Split
X_train, X_test, y_train, y_test = split_train_test(X, y, test_size=0.2, random_state=42)

# Preprocess
preprocessor = DataPreprocessor(scale=True, encode_categorical=True) # Scaling needed for distance-based models
X_train_proc = preprocessor.fit_transform(X_train)
X_test_proc = preprocessor.transform(X_test)

print(f"Training set: {X_train_proc.shape}")
print(f"Test set: {X_test_proc.shape}")
print(f"\nFeature names after preprocessing:")
print(preprocessor.get_feature_names())
# Out:
# ============================================================
# DataPreprocessor: fit_transform
# ============================================================
#
# 1. Column types:
#    Numerical: 5 columns
#    Nominal categorical: 2 columns
#    Ordinal categorical: 0 columns
#
# 2. Processing numerical columns...
#    ✓ Applied median imputation
#
# 3. Processing nominal categorical columns...
#    ✓ Applied most_frequent imputation
#    ✓ One-hot encoding 2 nominal columns...
#    → Created 5 one-hot features
#
# 4. Processing ordinal categorical columns...
#
# 6. Scaling features...
#    ✓ Scaled 5 features
#
# ============================================================
# Final shape: 712 rows × 10 features
# ============================================================
#
# Training set: (712, 10)
# Test set: (179, 10)
#
# Feature names after preprocessing:
# ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_female', 'Sex_male', 'Embarked_C', 'Embarked_Q', 'Embarked_S']

# %% [markdown]
# ## Baseline Model

# %%
model = KNN()
model.fit(X_train_proc, y_train)

baseline_score = model.score(X_test_proc, y_test)
print(f"Baseline accuracy: {baseline_score:.4f}")
# Out:
# Baseline accuracy: 0.8101

# %% [markdown]
# ## Baseline Evaluation & Diagnostics

# %%
print("\n" + "="*70)
print("BASELINE MODEL EVALUATION")
print("="*70)
print(f"Test Accuracy: {baseline_score:.4f}")

# Confusion matrix (brief)
print("\nConfusion Matrix:")
cm = model.confusion_matrix(X_test_proc, y_test)
# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# ======================================================================
# BASELINE MODEL EVALUATION
# ======================================================================
# Test Accuracy: 0.8101
#
# Confusion Matrix:

# %% [markdown]
# ## K-Fold Cross-Validation for Robust Evaluation

# %%
print("\n" + "="*70)
print("K-FOLD CROSS-VALIDATION")
print("="*70)

# Perform 5-fold cross-validation
cv_baseline = k_fold_cross_validation(
    model=model,  # Use same model as before
    X=X_train_proc,
    y=y_train,
    k=5,
    scoring='accuracy'
)

# Visualize
plot_cross_validation_results(cv_baseline)
# Out:
# ======================================================================
# K-FOLD CROSS-VALIDATION
# ======================================================================
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7692 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8169 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7535 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7676 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7949 ± 0.0420
# Min accuracy:  0.7535
# Max accuracy:  0.8671

# %% [markdown]
# ## Dimensionality Reduction Visualization

# %%
print("\n" + "="*70)
print("PCA vs LDA VISUALIZATION")
print("="*70)

lda = SKLearnLDA(n_components=2)
lda.fit(X_train_proc, y_train)
lda.plot_comparison_with_pca(X_train_proc, y_train)
# Out:
# ======================================================================
# PCA vs LDA VISUALIZATION
# ======================================================================
#
# ⚠️  LDA Auto-adjustment:
#    Requested n_components: 2
#    Maximum allowed (n_classes - 1): 1
#    Using: 1 component(s)
#
# 💡 Binary classification detected:
#    LDA can only produce 1 component for 2 classes
#    This finds the single best line to separate classes
#
# ======================================================================
# PCA vs LDA VISUALIZATION
# ======================================================================
# Number of classes: 2
# PCA type: Linear PCA
# PCA components: 2
# LDA components: 1
#
# 💡 Binary classification: Showing scatter plots + histograms
# ======================================================================
# KEY INSIGHTS (Binary Classification)
# ======================================================================
#
# 💡 Why LDA only has 1 component:
#    • For 2 classes, LDA can produce at most n_classes - 1 = 1 component
#    • This finds the single best line to separate the two classes
#
# 💡 Notice in the histograms:
#    • LDA (bottom right) shows better separation
#    • PCA: Linear variance maximization
#    • LDA: Supervised - maximizes class separation using labels
#
# ======================================================================
# VARIANCE EXPLAINED
# ======================================================================
#
# PCA: 58.0% total
#   PC1: 29.2%
#   PC2: 28.8%
#
# LDA: 100.0% total
#   LD1: 100.0%

# %% [markdown]
# ## Hyper-Parameter Tuning

# %%
print("\n" + "="*70)
print("HYPERPARAMETER TUNING")
print("="*70)

# Define parameter grid based on model
param_grid = {
    # KNN
    'n_neighbors': [3, 5, 7, 9, 11, 13, 15],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

grid_results = grid_search_cv(
    model_class=SKLearnKNNClassifier,
    param_grid=param_grid,
    X=X_train_proc,
    y=y_train,
    cv=5,
    verbose=True
)

# Visualize grid search results (if 2 parameters)
if len(param_grid) >= 2:
    param_names = list(param_grid.keys())
    plot_grid_search_results(grid_results, param_names[0], param_names[1])

print(f"\n✓ Best parameters: {grid_results['best_params']}")
print(f"✓ Best CV score: {grid_results['best_score']:.4f}")
# Out:
# ======================================================================
# HYPERPARAMETER TUNING
# ======================================================================
# ======================================================================
# GRID SEARCH WITH CROSS-VALIDATION
# ======================================================================
# Parameter grid:
#   n_neighbors: [3, 5, 7, 9, 11, 13, 15]
#   weights: ['uniform', 'distance']
#   metric: ['euclidean', 'manhattan']
#
# Total combinations to test: 28
# Cross-validation folds: 5
# Total fits: 140
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7692 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8531 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7676 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7949 ± 0.0311
# Min accuracy:  0.7676
# Max accuracy:  0.8531
# [1/28] {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'euclidean'}
#   → accuracy: 0.7949 ± 0.0311
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7832 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8531 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8028 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7817 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8033 ± 0.0261
# Min accuracy:  0.7817
# Max accuracy:  0.8531
# [2/28] {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'manhattan'}
#   → accuracy: 0.8033 ± 0.0261
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7692 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7746 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7183 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7850 ± 0.0505
# Min accuracy:  0.7183
# Max accuracy:  0.8741
# [3/28] {'n_neighbors': 3, 'weights': 'distance', 'metric': 'euclidean'}
#   → accuracy: 0.7850 ± 0.0505
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7762 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7324 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7920 ± 0.0460
# Min accuracy:  0.7324
# Max accuracy:  0.8741
# [4/28] {'n_neighbors': 3, 'weights': 'distance', 'metric': 'manhattan'}
#   → accuracy: 0.7920 ± 0.0460
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7692 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8169 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7535 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7676 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7949 ± 0.0420
# Min accuracy:  0.7535
# Max accuracy:  0.8671
# [5/28] {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'euclidean'}
#   → accuracy: 0.7949 ± 0.0420
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7762 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8601 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8169 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7887 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8061 ± 0.0301
# Min accuracy:  0.7762
# Max accuracy:  0.8601
# [6/28] {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan'}
#   → accuracy: 0.8061 ± 0.0301
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7762 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7535 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7324 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7864 ± 0.0488
# Min accuracy:  0.7324
# Max accuracy:  0.8741
# [7/28] {'n_neighbors': 5, 'weights': 'distance', 'metric': 'euclidean'}
#   → accuracy: 0.7864 ± 0.0488
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7902 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7817 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7535 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7963 ± 0.0378
# Min accuracy:  0.7535
# Max accuracy:  0.8671
# [8/28] {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}
#   → accuracy: 0.7963 ± 0.0378
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7692 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8028 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7676 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7746 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7977 ± 0.0403
# Min accuracy:  0.7676
# Max accuracy:  0.8741
# [9/28] {'n_neighbors': 7, 'weights': 'uniform', 'metric': 'euclidean'}
#   → accuracy: 0.7977 ± 0.0403
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7762 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8601 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8310 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7817 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8099 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8118 ± 0.0312
# Min accuracy:  0.7762
# Max accuracy:  0.8601
# [10/28] {'n_neighbors': 7, 'weights': 'uniform', 'metric': 'manhattan'}
#   → accuracy: 0.8118 ± 0.0312
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7762 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7817 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7817 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7465 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7934 ± 0.0458
# Min accuracy:  0.7465
# Max accuracy:  0.8811
# [11/28] {'n_neighbors': 7, 'weights': 'distance', 'metric': 'euclidean'}
#   → accuracy: 0.7934 ± 0.0458
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7692 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7817 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7606 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7935 ± 0.0381
# Min accuracy:  0.7606
# Max accuracy:  0.8671
# [12/28] {'n_neighbors': 7, 'weights': 'distance', 'metric': 'manhattan'}
#   → accuracy: 0.7935 ± 0.0381
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7832 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8169 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7465 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7817 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7991 ± 0.0407
# Min accuracy:  0.7465
# Max accuracy:  0.8671
# [13/28] {'n_neighbors': 9, 'weights': 'uniform', 'metric': 'euclidean'}
#   → accuracy: 0.7991 ± 0.0407
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7832 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8451 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7746 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7958 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8132 ± 0.0364
# Min accuracy:  0.7746
# Max accuracy:  0.8671
# [14/28] {'n_neighbors': 9, 'weights': 'uniform', 'metric': 'manhattan'}
#   → accuracy: 0.8132 ± 0.0364
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7622 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7606 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7394 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7850 ± 0.0472
# Min accuracy:  0.7394
# Max accuracy:  0.8741
# [15/28] {'n_neighbors': 9, 'weights': 'distance', 'metric': 'euclidean'}
#   → accuracy: 0.7850 ± 0.0472
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7622 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7676 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7977 ± 0.0374
# Min accuracy:  0.7622
# Max accuracy:  0.8671
# [16/28] {'n_neighbors': 9, 'weights': 'distance', 'metric': 'manhattan'}
#   → accuracy: 0.7977 ± 0.0374
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7972 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8601 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8169 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7606 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7958 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8061 ± 0.0325
# Min accuracy:  0.7606
# Max accuracy:  0.8601
# [17/28] {'n_neighbors': 11, 'weights': 'uniform', 'metric': 'euclidean'}
#   → accuracy: 0.8061 ± 0.0325
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7972 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8310 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8028 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8188 ± 0.0273
# Min accuracy:  0.7958
# Max accuracy:  0.8671
# [18/28] {'n_neighbors': 11, 'weights': 'uniform', 'metric': 'manhattan'}
#   → accuracy: 0.8188 ± 0.0273
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7692 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7817 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7746 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7465 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7892 ± 0.0441
# Min accuracy:  0.7465
# Max accuracy:  0.8741
# [19/28] {'n_neighbors': 11, 'weights': 'distance', 'metric': 'euclidean'}
#   → accuracy: 0.7892 ± 0.0441
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7762 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 4/5: accuracy=0.8028 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7746 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8033 ± 0.0368
# Min accuracy:  0.7746
# Max accuracy:  0.8741
# [20/28] {'n_neighbors': 11, 'weights': 'distance', 'metric': 'manhattan'}
#   → accuracy: 0.8033 ± 0.0368
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7972 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8531 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8310 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7817 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7746 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8075 ± 0.0300
# Min accuracy:  0.7746
# Max accuracy:  0.8531
# [21/28] {'n_neighbors': 13, 'weights': 'uniform', 'metric': 'euclidean'}
#   → accuracy: 0.8075 ± 0.0300
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7972 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8601 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8380 (train: 570, test: 142)
# Fold 4/5: accuracy=0.8099 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7887 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8188 ± 0.0266
# Min accuracy:  0.7887
# Max accuracy:  0.8601
# [22/28] {'n_neighbors': 13, 'weights': 'uniform', 'metric': 'manhattan'}
#   → accuracy: 0.8188 ± 0.0266
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7622 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7817 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7465 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7921 ± 0.0443
# Min accuracy:  0.7465
# Max accuracy:  0.8741
# [23/28] {'n_neighbors': 13, 'weights': 'distance', 'metric': 'euclidean'}
#   → accuracy: 0.7921 ± 0.0443
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7622 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7817 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7606 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7921 ± 0.0391
# Min accuracy:  0.7606
# Max accuracy:  0.8671
# [24/28] {'n_neighbors': 13, 'weights': 'distance', 'metric': 'manhattan'}
#   → accuracy: 0.7921 ± 0.0391
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7762 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8451 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8028 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8174 ± 0.0335
# Min accuracy:  0.7762
# Max accuracy:  0.8671
# [25/28] {'n_neighbors': 15, 'weights': 'uniform', 'metric': 'euclidean'}
#   → accuracy: 0.8174 ± 0.0335
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7832 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8521 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8099 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8230 ± 0.0345
# Min accuracy:  0.7832
# Max accuracy:  0.8741
# [26/28] {'n_neighbors': 15, 'weights': 'uniform', 'metric': 'manhattan'}
#   → accuracy: 0.8230 ± 0.0345
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7762 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8028 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7817 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7606 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7991 ± 0.0399
# Min accuracy:  0.7606
# Max accuracy:  0.8741
# [27/28] {'n_neighbors': 15, 'weights': 'distance', 'metric': 'euclidean'}
#   → accuracy: 0.7991 ± 0.0399
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7762 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8028 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7606 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8005 ± 0.0365
# Min accuracy:  0.7606
# Max accuracy:  0.8671
# [28/28] {'n_neighbors': 15, 'weights': 'distance', 'metric': 'manhattan'}
#   → accuracy: 0.8005 ± 0.0365
#
# ======================================================================
# GRID SEARCH RESULTS
# ======================================================================
#
# Best parameters: {'n_neighbors': 15, 'weights': 'uniform', 'metric': 'manhattan'}
# Best CV accuracy: 0.8230
#
# Top 5 parameter combinations:
#    n_neighbors  weights     metric  mean_score  std_score
# 0           15  uniform  manhattan    0.823018   0.034520
# 1           13  uniform  manhattan    0.818792   0.026567
# 2           11  uniform  manhattan    0.818783   0.027337
# 3           15  uniform  euclidean    0.817404   0.033511
# 4            9  uniform  manhattan    0.813169   0.036369
# ✓ Best parameters: {'n_neighbors': 15, 'weights': 'uniform', 'metric': 'manhattan'}
# ✓ Best CV score: 0.8230

# %% [markdown]
# ## Final Model Evaluation

# %%
best_model = grid_results['best_model']

final_score = best_model.score(X_test_proc, y_test)

print("\n" + "="*70)
print("FINAL MODEL EVALUATION")
print("="*70)
print(f"Test Accuracy: {final_score:.4f}")

print("\nConfusion Matrix:")
cm_final = best_model.confusion_matrix(X_test_proc, y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_final, annot=True, fmt='d', cmap='Blues')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix (Optimized Model)')
plt.show()

print("\nClassification Report:")
print(best_model.classification_report(X_test_proc, y_test))
# Out:
# ======================================================================
# FINAL MODEL EVALUATION
# ======================================================================
# Test Accuracy: 0.8101
#
# Confusion Matrix:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       105
#            1       0.81      0.70      0.75        74
#
#     accuracy                           0.81       179
#    macro avg       0.81      0.79      0.80       179
# weighted avg       0.81      0.81      0.81       179

# %% [markdown]
# ## Model Comparison

# %%
comparison_df = pd.DataFrame({
    'Model': ['Baseline (test)', 'Baseline (CV)', 'Optimized (CV)', 'Optimized (test)'],
    'Accuracy': [
        baseline_score,
        cv_baseline['mean'],
        grid_results['best_score'],
        final_score
    ],
    'Std': [None, cv_baseline['std'], None, None]
})

print("\n" + "="*70)
print("MODEL COMPARISON")
print("="*70)
print(comparison_df)

# Visualize comparison
plt.figure(figsize=(10, 6))
bars = plt.barh(comparison_df['Model'], comparison_df['Accuracy'])
bars[0].set_color('lightgray')
bars[1].set_color('gray')
bars[2].set_color('lightblue')
bars[3].set_color('blue')
plt.xlabel('Accuracy')
plt.title('Model Performance Progression')
plt.xlim(0, 1)
plt.grid(True, alpha=0.3, axis='x')
plt.tight_layout()
plt.show()

print(f"\n💡 Improvement from tuning: {(final_score - baseline_score)*100:.2f}%")
# Out:
# ======================================================================
# MODEL COMPARISON
# ======================================================================
#               Model  Accuracy       Std
# 0   Baseline (test)  0.810056       NaN
# 1     Baseline (CV)  0.794878  0.041995
# 2    Optimized (CV)  0.823018       NaN
# 3  Optimized (test)  0.810056       NaN
# 💡 Improvement from tuning: 0.00%

# %% [markdown]
# ## Key Insights & Summary

# %%
print("\n" + "="*70)
print("KEY INSIGHTS")
print("="*70)
print(f"\n✓ Baseline accuracy: {baseline_score:.4f}")
print(f"✓ Optimized accuracy: {final_score:.4f}")
print(f"✓ Improvement: {(final_score - baseline_score)*100:.2f}%")
print(f"\n✓ Best hyperparameters found:")
for param, value in grid_results['best_params'].items():
    print(f"   • {param}: {value}")
# Out:
# ======================================================================
# KEY INSIGHTS
# ======================================================================
#
# ✓ Baseline accuracy: 0.8101
# ✓ Optimized accuracy: 0.8101
# ✓ Improvement: 0.00%
#
# ✓ Best hyperparameters found:
#    • n_neighbors: 15
#    • weights: uniform
#    • metric: manhattan
