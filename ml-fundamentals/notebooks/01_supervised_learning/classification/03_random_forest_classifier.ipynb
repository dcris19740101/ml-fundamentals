# %% [markdown]
# # NOTEBOOK: Random Forest Classifier
#
#  Goal: Implement and evaluate Random Forest Classifier

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src import data_loader
from src.eda import (
    analyze_data,
    plot_feature_distributions_by_class
)
from src.preprocessing import DataPreprocessor
from src.data_utils import split_train_test
from src.models.supervised import SKLearnRandomForestClassifier, SKLearnLDA

from src.models.supervised.model_selection import (
    k_fold_cross_validation, 
    plot_cross_validation_results,
    grid_search_cv,
    plot_grid_search_results
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Data Loading & Exploration

# %%
# Load data
# Quick EDA: shape, dtypes, missing values, class distribution
# Feature/target split

X, y = data_loader.load_titanic()

analyze_data(X, show_stats=True)
plot_feature_distributions_by_class(X, y)
# Out:
# ======================================================================
# DATA ANALYSIS
# ======================================================================
#
# Dataset shape: 891 rows × 7 columns
#
# Data types:
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Embarked     object
# dtype: object
#
# Missing values:
#           Missing_Count  Missing_Percent
# Age                 177            19.87
# Embarked              2             0.22
#
# Numerical columns (5):
# ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
#
# Categorical columns (2):
# ['Sex', 'Embarked']
#
# Numerical features statistics:
#            Pclass         Age       SibSp       Parch        Fare
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200
# ======================================================================

# %% [markdown]
# ## Preprocess Data

# %%
# Split
X_train, X_test, y_train, y_test = split_train_test(X, y, test_size=0.2, random_state=42)

# Preprocess
preprocessor = DataPreprocessor(scale=False, encode_categorical=True) # No scaling for tree-based models
X_train_proc = preprocessor.fit_transform(X_train)
X_test_proc = preprocessor.transform(X_test)

print(f"Training set: {X_train_proc.shape}")
print(f"Test set: {X_test_proc.shape}")
print(f"\nFeature names after preprocessing:")
print(preprocessor.get_feature_names())
# Out:
# ============================================================
# DataPreprocessor: fit_transform
# ============================================================
#
# 1. Column types:
#    Numerical: 5 columns
#    Nominal categorical: 2 columns
#    Ordinal categorical: 0 columns
#
# 2. Processing numerical columns...
#    ✓ Applied median imputation
#
# 3. Processing nominal categorical columns...
#    ✓ Applied most_frequent imputation
#    ✓ One-hot encoding 2 nominal columns...
#    → Created 5 one-hot features
#
# 4. Processing ordinal categorical columns...
#
# ============================================================
# Final shape: 712 rows × 10 features
# ============================================================
#
# Training set: (712, 10)
# Test set: (179, 10)
#
# Feature names after preprocessing:
# ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_female', 'Sex_male', 'Embarked_C', 'Embarked_Q', 'Embarked_S']

# %% [markdown]
# ## Baseline Model

# %%
model = SKLearnRandomForestClassifier(n_estimators=100, max_depth=45, random_state=42)
model.fit(X_train_proc, y_train)

baseline_score = model.score(X_test_proc, y_test)
print(f"Baseline accuracy: {baseline_score:.4f}")
# Out:
# Baseline accuracy: 0.8045

# %% [markdown]
# ## Baseline Evaluation & Diagnostics

# %%
print("\n" + "="*70)
print("BASELINE MODEL EVALUATION")
print("="*70)
print(f"Test Accuracy: {baseline_score:.4f}")

# Confusion matrix (brief)
print("\nConfusion Matrix:")
cm = model.confusion_matrix(X_test_proc, y_test)
# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# ======================================================================
# BASELINE MODEL EVALUATION
# ======================================================================
# Test Accuracy: 0.8045
#
# Confusion Matrix:

# %% [markdown]
# ## K-Fold Cross-Validation for Robust Evaluation

# %%
print("\n" + "="*70)
print("K-FOLD CROSS-VALIDATION")
print("="*70)

# Perform 5-fold cross-validation
cv_baseline = k_fold_cross_validation(
    model=model,  # Use same model as before
    X=X_train_proc,
    y=y_train,
    k=5,
    scoring='accuracy'
)

# Visualize
plot_cross_validation_results(cv_baseline)
# Out:
# ======================================================================
# K-FOLD CROSS-VALIDATION
# ======================================================================
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7552 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7606 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7921 ± 0.0400
# Min accuracy:  0.7552
# Max accuracy:  0.8671

# %% [markdown]
# ## Dimensionality Reduction Visualization

# %%
print("\n" + "="*70)
print("PCA vs LDA VISUALIZATION")
print("="*70)

lda = SKLearnLDA(n_components=2)
lda.fit(X_train_proc, y_train)
lda.plot_comparison_with_pca(X_train_proc, y_train)
# Out:
# ======================================================================
# PCA vs LDA VISUALIZATION
# ======================================================================
#
# ⚠️  LDA Auto-adjustment:
#    Requested n_components: 2
#    Maximum allowed (n_classes - 1): 1
#    Using: 1 component(s)
#
# 💡 Binary classification detected:
#    LDA can only produce 1 component for 2 classes
#    This finds the single best line to separate classes
#
# ======================================================================
# PCA vs LDA VISUALIZATION
# ======================================================================
# Number of classes: 2
# PCA type: Linear PCA
# PCA components: 2
# LDA components: 1
#
# 💡 Binary classification: Showing scatter plots + histograms
# ======================================================================
# KEY INSIGHTS (Binary Classification)
# ======================================================================
#
# 💡 Why LDA only has 1 component:
#    • For 2 classes, LDA can produce at most n_classes - 1 = 1 component
#    • This finds the single best line to separate the two classes
#
# 💡 Notice in the histograms:
#    • LDA (bottom right) shows better separation
#    • PCA: Linear variance maximization
#    • LDA: Supervised - maximizes class separation using labels
#
# ======================================================================
# VARIANCE EXPLAINED
# ======================================================================
#
# PCA: 99.9% total
#   PC1: 94.0%
#   PC2: 5.8%
#
# LDA: 100.0% total
#   LD1: 100.0%

# %% [markdown]
# ## Hyper-Parameter Tuning

# %%
print("\n" + "="*70)
print("HYPERPARAMETER TUNING")
print("="*70)

# Define parameter grid based on model
param_grid = {
    # Random Forest
    'n_estimators': [50, 100, 200],
    'max_depth': [5, 10, 20, None],
    'min_samples_split': [2, 5, 10]
}

grid_results = grid_search_cv(
    model_class=SKLearnRandomForestClassifier,
    param_grid=param_grid,
    X=X_train_proc,
    y=y_train,
    cv=5,
    verbose=True
)

# Visualize grid search results (if 2 parameters)
if len(param_grid) >= 2:
    param_names = list(param_grid.keys())
    plot_grid_search_results(grid_results, param_names[0], param_names[1])

print(f"\n✓ Best parameters: {grid_results['best_params']}")
print(f"✓ Best CV score: {grid_results['best_score']:.4f}")
# Out:
# ======================================================================
# HYPERPARAMETER TUNING
# ======================================================================
# ======================================================================
# GRID SEARCH WITH CROSS-VALIDATION
# ======================================================================
# Parameter grid:
#   n_estimators: [50, 100, 200]
#   max_depth: [5, 10, 20, None]
#   min_samples_split: [2, 5, 10]
#
# Total combinations to test: 36
# Cross-validation folds: 5
# Total fits: 180
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7832 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8951 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8380 (train: 570, test: 142)
# Fold 4/5: accuracy=0.8028 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8239 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8286 ± 0.0381
# Min accuracy:  0.7832
# Max accuracy:  0.8951
# [1/36] {'n_estimators': 50, 'max_depth': 5, 'min_samples_split': 2, 'random_state': 42}
#   → accuracy: 0.8286 ± 0.0381
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7832 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8380 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8169 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8230 ± 0.0345
# Min accuracy:  0.7832
# Max accuracy:  0.8811
# [2/36] {'n_estimators': 50, 'max_depth': 5, 'min_samples_split': 5, 'random_state': 42}
#   → accuracy: 0.8230 ± 0.0345
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7902 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8380 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8310 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8272 ± 0.0328
# Min accuracy:  0.7902
# Max accuracy:  0.8811
# [3/36] {'n_estimators': 50, 'max_depth': 5, 'min_samples_split': 10, 'random_state': 42}
#   → accuracy: 0.8272 ± 0.0328
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7762 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8028 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8089 ± 0.0338
# Min accuracy:  0.7762
# Max accuracy:  0.8741
# [4/36] {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 2, 'random_state': 42}
#   → accuracy: 0.8089 ± 0.0338
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7762 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8099 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7746 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8239 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8104 ± 0.0342
# Min accuracy:  0.7746
# Max accuracy:  0.8671
# [5/36] {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 5, 'random_state': 42}
#   → accuracy: 0.8104 ± 0.0342
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7762 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8310 (train: 570, test: 142)
# Fold 4/5: accuracy=0.8028 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8239 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8230 ± 0.0348
# Min accuracy:  0.7762
# Max accuracy:  0.8811
# [6/36] {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 10, 'random_state': 42}
#   → accuracy: 0.8230 ± 0.0348
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7552 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8462 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7746 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7606 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7851 ± 0.0327
# Min accuracy:  0.7552
# Max accuracy:  0.8462
# [7/36] {'n_estimators': 50, 'max_depth': 20, 'min_samples_split': 2, 'random_state': 42}
#   → accuracy: 0.7851 ± 0.0327
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7692 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8239 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8028 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8104 ± 0.0335
# Min accuracy:  0.7692
# Max accuracy:  0.8671
# [8/36] {'n_estimators': 50, 'max_depth': 20, 'min_samples_split': 5, 'random_state': 42}
#   → accuracy: 0.8104 ± 0.0335
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7762 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8310 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8169 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8202 ± 0.0357
# Min accuracy:  0.7762
# Max accuracy:  0.8811
# [9/36] {'n_estimators': 50, 'max_depth': 20, 'min_samples_split': 10, 'random_state': 42}
#   → accuracy: 0.8202 ± 0.0357
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7622 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8462 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7817 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7606 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7879 ± 0.0311
# Min accuracy:  0.7606
# Max accuracy:  0.8462
# [10/36] {'n_estimators': 50, 'max_depth': None, 'min_samples_split': 2, 'random_state': 42}
#   → accuracy: 0.7879 ± 0.0311
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7692 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8239 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7817 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8028 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8090 ± 0.0345
# Min accuracy:  0.7692
# Max accuracy:  0.8671
# [11/36] {'n_estimators': 50, 'max_depth': None, 'min_samples_split': 5, 'random_state': 42}
#   → accuracy: 0.8090 ± 0.0345
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7762 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8310 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8169 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8202 ± 0.0357
# Min accuracy:  0.7762
# Max accuracy:  0.8811
# [12/36] {'n_estimators': 50, 'max_depth': None, 'min_samples_split': 10, 'random_state': 42}
#   → accuracy: 0.8202 ± 0.0357
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7902 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8380 (train: 570, test: 142)
# Fold 4/5: accuracy=0.8028 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8099 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8244 ± 0.0324
# Min accuracy:  0.7902
# Max accuracy:  0.8811
# [13/36] {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 2, 'random_state': 42}
#   → accuracy: 0.8244 ± 0.0324
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7832 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8451 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8099 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8230 ± 0.0357
# Min accuracy:  0.7832
# Max accuracy:  0.8811
# [14/36] {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 5, 'random_state': 42}
#   → accuracy: 0.8230 ± 0.0357
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7902 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8451 (train: 570, test: 142)
# Fold 4/5: accuracy=0.8099 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8169 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8272 ± 0.0293
# Min accuracy:  0.7902
# Max accuracy:  0.8741
# [15/36] {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 10, 'random_state': 42}
#   → accuracy: 0.8272 ± 0.0293
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7622 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8099 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7958 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8061 ± 0.0373
# Min accuracy:  0.7622
# Max accuracy:  0.8741
# [16/36] {'n_estimators': 100, 'max_depth': 10, 'min_samples_split': 2, 'random_state': 42}
#   → accuracy: 0.8061 ± 0.0373
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7902 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8239 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8169 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8202 ± 0.0335
# Min accuracy:  0.7887
# Max accuracy:  0.8811
# [17/36] {'n_estimators': 100, 'max_depth': 10, 'min_samples_split': 5, 'random_state': 42}
#   → accuracy: 0.8202 ± 0.0335
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7902 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8380 (train: 570, test: 142)
# Fold 4/5: accuracy=0.8028 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8239 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8272 ± 0.0316
# Min accuracy:  0.7902
# Max accuracy:  0.8811
# [18/36] {'n_estimators': 100, 'max_depth': 10, 'min_samples_split': 10, 'random_state': 42}
#   → accuracy: 0.8272 ± 0.0316
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7552 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7606 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7935 ± 0.0400
# Min accuracy:  0.7552
# Max accuracy:  0.8671
# [19/36] {'n_estimators': 100, 'max_depth': 20, 'min_samples_split': 2, 'random_state': 42}
#   → accuracy: 0.7935 ± 0.0400
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7832 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8169 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8169 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8160 ± 0.0322
# Min accuracy:  0.7832
# Max accuracy:  0.8741
# [20/36] {'n_estimators': 100, 'max_depth': 20, 'min_samples_split': 5, 'random_state': 42}
#   → accuracy: 0.8160 ± 0.0322
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7832 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8380 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8169 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8216 ± 0.0322
# Min accuracy:  0.7832
# Max accuracy:  0.8741
# [21/36] {'n_estimators': 100, 'max_depth': 20, 'min_samples_split': 10, 'random_state': 42}
#   → accuracy: 0.8216 ± 0.0322
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7552 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8671 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7606 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7921 ± 0.0400
# Min accuracy:  0.7552
# Max accuracy:  0.8671
# [22/36] {'n_estimators': 100, 'max_depth': None, 'min_samples_split': 2, 'random_state': 42}
#   → accuracy: 0.7921 ± 0.0400
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7902 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8169 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8169 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8174 ± 0.0309
# Min accuracy:  0.7887
# Max accuracy:  0.8741
# [23/36] {'n_estimators': 100, 'max_depth': None, 'min_samples_split': 5, 'random_state': 42}
#   → accuracy: 0.8174 ± 0.0309
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7832 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8380 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8169 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8216 ± 0.0322
# Min accuracy:  0.7832
# Max accuracy:  0.8741
# [24/36] {'n_estimators': 100, 'max_depth': None, 'min_samples_split': 10, 'random_state': 42}
#   → accuracy: 0.8216 ± 0.0322
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7902 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8380 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8239 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8258 ± 0.0328
# Min accuracy:  0.7902
# Max accuracy:  0.8811
# [25/36] {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 2, 'random_state': 42}
#   → accuracy: 0.8258 ± 0.0328
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7832 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8380 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8169 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8230 ± 0.0345
# Min accuracy:  0.7832
# Max accuracy:  0.8811
# [26/36] {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 5, 'random_state': 42}
#   → accuracy: 0.8230 ± 0.0345
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7902 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8451 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8239 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8258 ± 0.0349
# Min accuracy:  0.7887
# Max accuracy:  0.8811
# [27/36] {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 10, 'random_state': 42}
#   → accuracy: 0.8258 ± 0.0349
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7692 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8099 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8028 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8104 ± 0.0380
# Min accuracy:  0.7692
# Max accuracy:  0.8811
# [28/36] {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 2, 'random_state': 42}
#   → accuracy: 0.8104 ± 0.0380
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7832 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8169 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8099 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8146 ± 0.0323
# Min accuracy:  0.7832
# Max accuracy:  0.8741
# [29/36] {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 5, 'random_state': 42}
#   → accuracy: 0.8146 ± 0.0323
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7902 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8310 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8310 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8244 ± 0.0339
# Min accuracy:  0.7887
# Max accuracy:  0.8811
# [30/36] {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 10, 'random_state': 42}
#   → accuracy: 0.8244 ± 0.0339
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7622 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7606 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7949 ± 0.0415
# Min accuracy:  0.7606
# Max accuracy:  0.8741
# [31/36] {'n_estimators': 200, 'max_depth': 20, 'min_samples_split': 2, 'random_state': 42}
#   → accuracy: 0.7949 ± 0.0415
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7972 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8099 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7817 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8239 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8174 ± 0.0316
# Min accuracy:  0.7817
# Max accuracy:  0.8741
# [32/36] {'n_estimators': 200, 'max_depth': 20, 'min_samples_split': 5, 'random_state': 42}
#   → accuracy: 0.8174 ± 0.0316
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7902 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8380 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8169 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8244 ± 0.0330
# Min accuracy:  0.7902
# Max accuracy:  0.8811
# [33/36] {'n_estimators': 200, 'max_depth': 20, 'min_samples_split': 10, 'random_state': 42}
#   → accuracy: 0.8244 ± 0.0330
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7622 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8741 (train: 569, test: 143)
# Fold 3/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7887 (train: 570, test: 142)
# Fold 5/5: accuracy=0.7676 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.7963 ± 0.0404
# Min accuracy:  0.7622
# Max accuracy:  0.8741
# [34/36] {'n_estimators': 200, 'max_depth': None, 'min_samples_split': 2, 'random_state': 42}
#   → accuracy: 0.7963 ± 0.0404
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7902 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8169 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7817 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8239 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8188 ± 0.0350
# Min accuracy:  0.7817
# Max accuracy:  0.8811
# [35/36] {'n_estimators': 200, 'max_depth': None, 'min_samples_split': 5, 'random_state': 42}
#   → accuracy: 0.8188 ± 0.0350
#
# ======================================================================
# K-FOLD CROSS-VALIDATION (k=5)
# ======================================================================
# Task: Classification
# Scoring: accuracy
# Total samples: 712
#
# Fold 1/5: accuracy=0.7902 (train: 569, test: 143)
# Fold 2/5: accuracy=0.8811 (train: 569, test: 143)
# Fold 3/5: accuracy=0.8380 (train: 570, test: 142)
# Fold 4/5: accuracy=0.7958 (train: 570, test: 142)
# Fold 5/5: accuracy=0.8169 (train: 570, test: 142)
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Mean accuracy: 0.8244 ± 0.0330
# Min accuracy:  0.7902
# Max accuracy:  0.8811
# [36/36] {'n_estimators': 200, 'max_depth': None, 'min_samples_split': 10, 'random_state': 42}
#   → accuracy: 0.8244 ± 0.0330
#
# ======================================================================
# GRID SEARCH RESULTS
# ======================================================================
#
# Best parameters: {'n_estimators': 50, 'max_depth': 5, 'min_samples_split': 2, 'random_state': 42}
# Best CV accuracy: 0.8286
#
# Top 5 parameter combinations:
#    n_estimators  max_depth  min_samples_split  random_state  mean_score  \
# 0            50        5.0                  2            42    0.828622
# 1           100        5.0                 10            42    0.827233
# 2            50        5.0                 10            42    0.827223
# 3           100       10.0                 10            42    0.827223
# 4           200        5.0                 10            42    0.825815
#
#    std_score
# 0   0.038100
# 1   0.029314
# 2   0.032847
# 3   0.031616
# 4   0.034859
# ✓ Best parameters: {'n_estimators': 50, 'max_depth': 5, 'min_samples_split': 2, 'random_state': 42}
# ✓ Best CV score: 0.8286

# %% [markdown]
# ## Final Model Evaluation

# %%
best_model = grid_results['best_model']

final_score = best_model.score(X_test_proc, y_test)

print("\n" + "="*70)
print("FINAL MODEL EVALUATION")
print("="*70)
print(f"Test Accuracy: {final_score:.4f}")

print("\nConfusion Matrix:")
cm_final = best_model.confusion_matrix(X_test_proc, y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_final, annot=True, fmt='d', cmap='Blues')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix (Optimized Model)')
plt.show()

print("\nClassification Report:")
print(best_model.classification_report(X_test_proc, y_test))
# Out:
# ======================================================================
# FINAL MODEL EVALUATION
# ======================================================================
# Test Accuracy: 0.8156
#
# Confusion Matrix:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85       105
#            1       0.84      0.69      0.76        74
#
#     accuracy                           0.82       179
#    macro avg       0.82      0.80      0.80       179
# weighted avg       0.82      0.82      0.81       179

# %% [markdown]
# ## Model Comparison

# %%
comparison_df = pd.DataFrame({
    'Model': ['Baseline (test)', 'Baseline (CV)', 'Optimized (CV)', 'Optimized (test)'],
    'Accuracy': [
        baseline_score,
        cv_baseline['mean'],
        grid_results['best_score'],
        final_score
    ],
    'Std': [None, cv_baseline['std'], None, None]
})

print("\n" + "="*70)
print("MODEL COMPARISON")
print("="*70)
print(comparison_df)

# Visualize comparison
plt.figure(figsize=(10, 6))
bars = plt.barh(comparison_df['Model'], comparison_df['Accuracy'])
bars[0].set_color('lightgray')
bars[1].set_color('gray')
bars[2].set_color('lightblue')
bars[3].set_color('blue')
plt.xlabel('Accuracy')
plt.title('Model Performance Progression')
plt.xlim(0, 1)
plt.grid(True, alpha=0.3, axis='x')
plt.tight_layout()
plt.show()

print(f"\n💡 Improvement from tuning: {(final_score - baseline_score)*100:.2f}%")
# Out:
# ======================================================================
# MODEL COMPARISON
# ======================================================================
#               Model  Accuracy       Std
# 0   Baseline (test)  0.804469       NaN
# 1     Baseline (CV)  0.792081  0.040014
# 2    Optimized (CV)  0.828622       NaN
# 3  Optimized (test)  0.815642       NaN
# 💡 Improvement from tuning: 1.12%

# %% [markdown]
# ## Feature Importance

# %%
if hasattr(best_model, 'feature_importances_'):
    print("\n" + "="*70)
    print("FEATURE IMPORTANCE")
    print("="*70)
    
    importances = best_model.feature_importances_
    feature_names = preprocessor.get_feature_names()
    
    # Sort and plot top 10
    indices = np.argsort(importances)[-10:]
    
    plt.figure(figsize=(10, 6))
    plt.barh(range(len(indices)), importances[indices], color='steelblue')
    plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
    plt.xlabel('Importance')
    plt.title('Top 10 Feature Importances')
    plt.grid(True, alpha=0.3, axis='x')
    plt.tight_layout()
    plt.show()
    
    print("\n💡 Most important features:")
    for idx in indices[::-1][:5]:  # Top 5
        print(f"   • {feature_names[idx]}: {importances[idx]:.4f}")
# Out:
# ======================================================================
# FEATURE IMPORTANCE
# ======================================================================
# 💡 Most important features:
#    • Sex_male: 0.2912
#    • Sex_female: 0.2266
#    • Pclass: 0.1392
#    • Fare: 0.1292
#    • Age: 0.0925

# %% [markdown]
# ## Key Insights & Summary

# %%
print("\n" + "="*70)
print("KEY INSIGHTS")
print("="*70)
print(f"\n✓ Baseline accuracy: {baseline_score:.4f}")
print(f"✓ Optimized accuracy: {final_score:.4f}")
print(f"✓ Improvement: {(final_score - baseline_score)*100:.2f}%")
print(f"\n✓ Best hyperparameters found:")
for param, value in grid_results['best_params'].items():
    print(f"   • {param}: {value}")
# Out:
# ======================================================================
# KEY INSIGHTS
# ======================================================================
#
# ✓ Baseline accuracy: 0.8045
# ✓ Optimized accuracy: 0.8156
# ✓ Improvement: 1.12%
#
# ✓ Best hyperparameters found:
#    • n_estimators: 50
#    • max_depth: 5
#    • min_samples_split: 2
#    • random_state: 42
